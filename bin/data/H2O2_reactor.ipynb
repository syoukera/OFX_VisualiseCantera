# %% [markdown]
# Constant-pressure, adiabatic kinetics simulation.
#
# Requires: cantera >= 2.5.0, matplotlib >= 2.0
# Keywords: combustion, reactor network, plotting

# %%
import sys
import numpy as np
import pandas as pd
import cantera as ct

# %%
gas = ct.Solution('h2o2.yaml')
gas.TPX = 1001.0, ct.one_atm, 'H2:2,O2:1,N2:4'
r = ct.IdealGasConstPressureReactor(gas)

sim = ct.ReactorNet([r])
sim.verbose = True

# limit advance when temperature difference is exceeded
delta_T_max = 20.
r.set_advance_limit('temperature', delta_T_max)

dt_max = 1.e-5
t_end = 100 * dt_max
states = ct.SolutionArray(gas, extra=['t'])

print('{:10s} {:10s} {:10s} {:14s}'.format(
    't [s]', 'T [K]', 'P [Pa]', 'u [J/kg]'))
while sim.time < t_end:
    sim.advance(sim.time + dt_max)
    states.append(r.thermo.state, t=sim.time*1e3)
    print('{:10.3e} {:10.3f} {:10.3f} {:14.6f}'.format(
            sim.time, r.T, r.thermo.P, r.thermo.u))
# Out:
# Initializing reactor network.
# Reactor 0: 12 variables.
#               0 sensitivity params.
# Number of equations: 12
# Maximum time step:                0
# t [s]      T [K]      P [Pa]     u [J/kg]
#  1.000e-05   1001.000 101325.000  620761.940774
#  2.000e-05   1001.000 101325.000  620761.940024
#  3.000e-05   1001.000 101325.000  620761.937443
#  4.000e-05   1001.000 101325.000  620761.932033
#  5.000e-05   1001.000 101325.000  620761.922251
#  6.000e-05   1001.000 101325.000  620761.905712
#  7.000e-05   1001.000 101325.000  620761.878725
#  8.000e-05   1001.000 101325.000  620761.835580
#  9.000e-05   1001.001 101325.000  620761.767437
#  1.000e-04   1001.001 101325.000  620761.660607
#  1.100e-04   1001.001 101325.000  620761.493864
#  1.200e-04   1001.002 101325.000  620761.234248
#  1.300e-04   1001.003 101325.000  620760.830463
#  1.400e-04   1001.005 101325.000  620760.202386
#  1.500e-04   1001.008 101325.000  620759.224189
#  1.600e-04   1001.012 101325.000  620757.696642
#  1.700e-04   1001.019 101325.000  620755.300403
#  1.800e-04   1001.030 101325.000  620751.514343
#  1.900e-04   1001.048 101325.000  620745.465936
#  2.000e-04   1001.076 101325.000  620735.641598
#  2.100e-04   1001.124 101325.000  620719.289981
#  2.200e-04   1001.204 101325.000  620691.109787
#  2.300e-04   1001.349 101325.000  620640.173038
#  2.400e-04   1001.623 101325.000  620542.299510
#  2.500e-04   1002.182 101325.000  620340.602686
#  2.600e-04   1003.397 101325.000  619897.667914
#  2.700e-04   1006.134 101325.000  618893.694074
#  2.800e-04   1012.324 101325.000  616618.206745
#  2.900e-04   1026.776 101325.000  611309.993847
#     Limiting global state vector component 1 (dt =     1e-05):    37.7079 >        20
#  2.950e-04   1040.882 101325.000  606137.126425
#     Limiting global state vector component 1 (dt =     1e-05):    67.2368 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    23.8769 >        20
#  2.975e-04   1051.164 101325.000  602371.487295
#     Limiting global state vector component 1 (dt =     1e-05):    93.9215 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    32.0613 >        20
#  3.000e-04   1064.775 101325.000  597393.368098
#     Limiting global state vector component 1 (dt =     1e-05):    136.833 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     44.381 >        20
#  3.025e-04   1083.260 101325.000  590644.956051
#     Limiting global state vector component 1 (dt =     1e-05):    213.457 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    64.1412 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    25.9868 >        20
#  3.038e-04   1095.086 101325.000  586334.638376
#     Limiting global state vector component 1 (dt =     1e-05):    273.708 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    78.6964 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    31.3396 >        20
#  3.050e-04   1109.250 101325.000  581179.574385
#     Limiting global state vector component 1 (dt =     1e-05):    358.491 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    98.1841 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     38.326 >        20
#  3.063e-04   1126.431 101325.000  574936.977616
#     Limiting global state vector component 1 (dt =     1e-05):    483.183 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    124.957 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    47.6408 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    21.1544 >        20
#  3.069e-04   1136.438 101325.000  571306.548424
#     Limiting global state vector component 1 (dt =     1e-05):    562.674 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    141.945 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    53.4718 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    23.6213 >        20
#  3.075e-04   1147.586 101325.000  567266.817260
#     Limiting global state vector component 1 (dt =     1e-05):    655.304 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    161.941 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    60.2979 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    26.4955 >        20
#  3.081e-04   1160.060 101325.000  562752.407328
#     Limiting global state vector component 1 (dt =     1e-05):    759.775 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    185.376 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    68.3113 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     29.859 >        20
#  3.088e-04   1174.082 101325.000  557685.008242
#     Limiting global state vector component 1 (dt =     1e-05):    868.917 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    212.465 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    77.7189 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    33.8072 >        20
#  3.094e-04   1189.919 101325.000  551971.071480
#     Limiting global state vector component 1 (dt =     1e-05):    955.051 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    242.578 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    88.7024 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    38.4451 >        20
#  3.100e-04   1207.888 101325.000  545499.819076
#     Limiting global state vector component 1 (dt =     1e-05):    976.966 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    274.163 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    101.371 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    43.8759 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    20.4741 >        20
#  3.103e-04   1217.787 101325.000  541940.650602
#     Limiting global state vector component 1 (dt =     1e-05):    948.853 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    289.678 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    108.325 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     46.914 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    21.8816 >        20
#  3.106e-04   1228.362 101325.000  538142.580923
#     Limiting global state vector component 1 (dt =     1e-05):    874.588 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    303.948 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    115.633 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    50.1723 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    23.3988 >        20
#  3.109e-04   1239.668 101325.000  534087.175073
#     Limiting global state vector component 1 (dt =     1e-05):    676.597 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    313.817 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    123.128 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    53.6414 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    25.0275 >        20
#  3.113e-04   1251.761 101325.000  529755.591823
#     Limiting global state vector component 1 (dt =     1e-05):    433.656 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    321.251 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    130.795 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):     57.309 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    26.7657 >        20
#  3.116e-04   1264.696 101325.000  525129.174276
#     Limiting global state vector component 1 (dt =     1e-05):    79.2557 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    322.993 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    138.373 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    61.1381 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    28.6055 >        20
#  3.119e-04   1278.526 101325.000  520190.330364
#     Limiting global state vector component 1 (dt =     1e-05):    568.174 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    311.509 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    145.376 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    65.0625 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    30.5305 >        20
#  3.122e-04   1293.300 101325.000  514923.786027
#     Limiting global state vector component 1 (dt =     1e-05):     1370.8 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    290.015 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    151.645 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    69.0062 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    32.5145 >        20
#  3.125e-04   1309.056 101325.000  509318.289186
#     Limiting global state vector component 1 (dt =     1e-05):    2132.61 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    263.044 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    156.959 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    72.8582 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     34.517 >        20
#  3.128e-04   1325.815 101325.000  503368.815126
#     Limiting global state vector component 1 (dt =     1e-05):    2977.42 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    225.067 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    160.707 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    76.4612 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     36.481 >        20
#  3.131e-04   1343.573 101325.000  497079.250399
#     Limiting global state vector component 1 (dt =     1e-05):    3493.83 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    188.707 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    162.879 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    79.6488 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    38.3331 >        20
#  3.134e-04   1362.296 101325.000  490465.396971
#     Limiting global state vector component 1 (dt =     1e-05):    3597.55 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    157.412 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    163.227 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    82.2257 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    39.9835 >        20
#  3.137e-04   1381.906 101325.000  483557.927445
#     Limiting global state vector component 1 (dt =     1e-05):    2439.07 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    161.829 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    162.606 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.0379 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    41.3339 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.3737 >        20
#  3.139e-04   1392.008 101325.000  480008.325060
#     Limiting global state vector component 1 (dt =     1e-05):     1632.8 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    170.949 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    161.728 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.5991 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     41.865 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.6925 >        20
#  3.141e-04   1402.280 101325.000  476404.658353
#     Limiting global state vector component 1 (dt =     1e-05):    1302.46 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    165.587 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    159.891 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.8902 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     42.284 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):     20.961 >        20
#  3.142e-04   1412.700 101325.000  472755.704072
#     Limiting global state vector component 1 (dt =     1e-05):    526.557 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    210.572 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    159.329 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.9822 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.5845 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.1737 >        20
#  3.144e-04   1423.241 101325.000  469071.270879
#     Limiting global state vector component 1 (dt =     1e-05):     1572.3 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    232.479 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    157.634 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.7844 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.7554 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.3254 >        20
#  3.145e-04   1433.874 101325.000  465362.073183
#     Limiting global state vector component 1 (dt =     1e-05):    3345.56 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    281.763 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    156.638 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    84.3693 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.7949 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.4125 >        20
#  3.147e-04   1444.567 101325.000  461639.553304
#     Limiting global state vector component 1 (dt =     1e-05):    5496.82 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     347.06 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    156.015 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    83.7322 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.7005 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.4325 >        20
#  3.148e-04   1455.286 101325.000  457915.654323
#     Limiting global state vector component 1 (dt =     1e-05):    6563.73 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    381.244 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    154.274 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    82.8356 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.4717 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.3842 >        20
#  3.150e-04   1465.999 101325.000  454202.551174
#     Limiting global state vector component 1 (dt =     1e-05):    7489.38 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    414.791 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    152.513 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    81.7396 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    42.1149 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.2685 >        20
#  3.152e-04   1476.671 101325.000  450512.352579
#     Limiting global state vector component 1 (dt =     1e-05):    8222.33 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    445.379 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    150.698 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    80.4669 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    41.6383 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    21.0879 >        20
#  3.153e-04   1487.268 101325.000  446856.789708
#     Limiting global state vector component 1 (dt =     1e-05):    8229.12 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    454.898 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    148.252 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    79.0238 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    41.0518 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.8463 >        20
#  3.155e-04   1497.759 101325.000  443246.910898
#     Limiting global state vector component 1 (dt =     1e-05):    8090.79 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    460.809 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    145.749 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    77.4575 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    40.3696 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):    20.5494 >        20
#  3.156e-04   1508.114 101325.000  439692.802214
#     Limiting global state vector component 1 (dt =     1e-05):    6256.84 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    412.506 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    141.533 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    75.7399 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    39.6044 >        20
#     Limiting global state vector component 1 (dt = 3.125e-07):     20.204 >        20
#  3.158e-04   1518.308 101325.000  436203.352191
#     Limiting global state vector component 1 (dt =     1e-05):    6525.45 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    429.933 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    139.475 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    74.0283 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    38.7768 >        20
#  3.161e-04   1538.126 101325.000  429447.004518
#     Limiting global state vector component 1 (dt =     1e-05):     1830.6 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    291.794 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    129.773 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    70.3168 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    36.9839 >        20
#  3.164e-04   1557.081 101325.000  423020.045211
#     Limiting global state vector component 1 (dt =     1e-05):    446.398 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     219.82 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    122.155 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    66.6781 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    35.1173 >        20
#  3.167e-04   1575.108 101325.000  416941.309340
#     Limiting global state vector component 1 (dt =     1e-05):    2475.89 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    145.592 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    114.393 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    63.1592 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    33.2711 >        20
#  3.170e-04   1592.197 101325.000  411209.708210
#     Limiting global state vector component 1 (dt =     1e-05):    3093.09 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    110.878 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    108.031 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    59.8947 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    31.5153 >        20
#  3.173e-04   1608.379 101325.000  405809.688955
#     Limiting global state vector component 1 (dt =     1e-05):    2707.17 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    106.759 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    102.943 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    56.9203 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    29.8884 >        20
#  3.177e-04   1623.713 101325.000  400717.041035
#     Limiting global state vector component 1 (dt =     1e-05):    2019.68 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    113.563 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     98.594 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    54.2262 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    28.4048 >        20
#  3.180e-04   1638.268 101325.000  395903.830878
#     Limiting global state vector component 1 (dt =     1e-05):    1256.37 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    125.457 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    94.8426 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    51.7969 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    27.0632 >        20
#  3.183e-04   1652.118 101325.000  391341.919206
#     Limiting global state vector component 1 (dt =     1e-05):    490.759 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    140.353 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    91.6168 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    49.6081 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    25.8535 >        20
#  3.186e-04   1665.332 101325.000  387005.062587
#     Limiting global state vector component 1 (dt =     1e-05):    66.7068 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    146.495 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    88.4675 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    47.6167 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    24.7604 >        20
#  3.189e-04   1677.972 101325.000  382869.897124
#     Limiting global state vector component 1 (dt =     1e-05):    226.729 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    150.134 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    85.5526 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    45.8023 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    23.7691 >        20
#  3.192e-04   1690.093 101325.000  378916.179592
#     Limiting global state vector component 1 (dt =     1e-05):    308.251 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    147.976 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    82.7028 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    44.1346 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):     22.865 >        20
#  3.195e-04   1701.741 101325.000  375126.611207
#     Limiting global state vector component 1 (dt =     1e-05):    388.543 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    146.556 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    80.1019 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    42.6007 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    22.0362 >        20
#  3.198e-04   1712.958 101325.000  371486.473941
#     Limiting global state vector component 1 (dt =     1e-05):    390.627 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     142.99 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    77.6103 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    41.1781 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    21.2721 >        20
#  3.202e-04   1723.778 101325.000  367983.219015
#     Limiting global state vector component 1 (dt =     1e-05):    372.014 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    139.023 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    75.2633 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    39.8543 >        20
#     Limiting global state vector component 1 (dt =  6.25e-07):    20.5639 >        20
#  3.205e-04   1734.230 101325.000  364606.079738
#     Limiting global state vector component 1 (dt =     1e-05):    343.931 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     134.93 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    73.0498 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    38.6176 >        20
#  3.211e-04   1754.135 101325.000  358194.054514
#     Limiting global state vector component 1 (dt =     1e-05):    291.874 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    127.286 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    68.9958 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    36.3691 >        20
#  3.217e-04   1772.846 101325.000  352188.724396
#     Limiting global state vector component 1 (dt =     1e-05):    246.602 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     120.31 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    65.3648 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    34.3724 >        20
#  3.223e-04   1790.503 101325.000  346541.357455
#     Limiting global state vector component 1 (dt =     1e-05):    222.914 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    114.461 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    62.1084 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    32.5846 >        20
#  3.230e-04   1807.218 101325.000  341212.266112
#     Limiting global state vector component 1 (dt =     1e-05):    207.227 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    109.268 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    59.1611 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    30.9727 >        20
#  3.236e-04   1823.087 101325.000  336168.391727
#     Limiting global state vector component 1 (dt =     1e-05):    194.143 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    104.522 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    56.4762 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    29.5107 >        20
#  3.242e-04   1838.191 101325.000  331381.744858
#     Limiting global state vector component 1 (dt =     1e-05):    183.699 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    100.193 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    54.0208 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    28.1783 >        20
#  3.248e-04   1852.598 101325.000  326828.341078
#     Limiting global state vector component 1 (dt =     1e-05):    175.192 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    96.2254 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    51.7662 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    26.9587 >        20
#  3.255e-04   1866.369 101325.000  322487.435539
#     Limiting global state vector component 1 (dt =     1e-05):      167.4 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    92.5484 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    49.6875 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    25.8379 >        20
#  3.261e-04   1879.556 101325.000  318340.948303
#     Limiting global state vector component 1 (dt =     1e-05):    161.171 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    89.1638 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    47.7659 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    24.8042 >        20
#  3.267e-04   1892.207 101325.000  314373.019110
#     Limiting global state vector component 1 (dt =     1e-05):    155.337 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    86.0083 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    45.9829 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    23.8478 >        20
#  3.273e-04   1904.361 101325.000  310569.654703
#     Limiting global state vector component 1 (dt =     1e-05):    118.638 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     82.064 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    44.2917 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    22.9591 >        20
#  3.280e-04   1916.054 101325.000  306918.444967
#     Limiting global state vector component 1 (dt =     1e-05):    140.291 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    80.1452 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     42.771 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    22.1338 >        20
#  3.286e-04   1927.321 101325.000  303408.331680
#     Limiting global state vector component 1 (dt =     1e-05):     136.74 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    77.6008 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     41.326 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    21.3631 >        20
#  3.292e-04   1938.188 101325.000  300029.418335
#     Limiting global state vector component 1 (dt =     1e-05):    132.972 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    75.1833 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    39.9702 >        20
#     Limiting global state vector component 1 (dt =  1.25e-06):    20.6422 >        20
#  3.298e-04   1948.684 101325.000  296772.812524
#     Limiting global state vector component 1 (dt =     1e-05):    129.544 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    72.9163 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    38.6978 >        20
#  3.311e-04   1968.651 101325.000  290595.204443
#     Limiting global state vector component 1 (dt =     1e-05):    123.107 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    68.7499 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    36.3715 >        20
#  3.323e-04   1987.385 101325.000  284819.936993
#     Limiting global state vector component 1 (dt =     1e-05):    117.174 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    65.0098 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     34.297 >        20
#  3.336e-04   2005.025 101325.000  279400.944894
#     Limiting global state vector component 1 (dt =     1e-05):    111.794 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    61.6395 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    32.4355 >        20
#  3.348e-04   2021.684 101325.000  274299.614047
#     Limiting global state vector component 1 (dt =     1e-05):     106.51 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     58.561 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     30.754 >        20
#  3.361e-04   2037.461 101325.000  269483.255133
#     Limiting global state vector component 1 (dt =     1e-05):    102.046 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    55.7839 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    29.2307 >        20
#  3.373e-04   2052.440 101325.000  264923.950334
#     Limiting global state vector component 1 (dt =     1e-05):    97.6958 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    53.2282 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    27.8415 >        20
#  3.386e-04   2066.693 101325.000  260597.666685
#     Limiting global state vector component 1 (dt =     1e-05):    93.7074 >        20
#     Limiting global state vector component 1 (dt =     5e-06):     50.884 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    26.5704 >        20
#  3.398e-04   2080.282 101325.000  256483.568083
#     Limiting global state vector component 1 (dt =     1e-05):    90.0076 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    48.7239 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    25.4028 >        20
#  3.411e-04   2093.263 101325.000  252563.472370
#     Limiting global state vector component 1 (dt =     1e-05):    86.5689 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    46.7272 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    24.3266 >        20
#  3.423e-04   2105.685 101325.000  248821.419499
#     Limiting global state vector component 1 (dt =     1e-05):     83.348 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    44.8748 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    23.3313 >        20
#  3.436e-04   2117.590 101325.000  245243.324024
#     Limiting global state vector component 1 (dt =     1e-05):     80.317 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    43.1511 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    22.4081 >        20
#  3.448e-04   2129.017 101325.000  241816.693059
#     Limiting global state vector component 1 (dt =     1e-05):    77.4982 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    41.5456 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    21.5497 >        20
#  3.461e-04   2139.999 101325.000  238530.395623
#     Limiting global state vector component 1 (dt =     1e-05):    74.8288 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    40.0437 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):    20.7491 >        20
#  3.473e-04   2150.567 101325.000  235374.471937
#     Limiting global state vector component 1 (dt =     1e-05):    72.3443 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    38.6391 >        20
#     Limiting global state vector component 1 (dt =   2.5e-06):     20.001 >        20
#  3.486e-04   2160.748 101325.000  232339.975152
#     Limiting global state vector component 1 (dt =     1e-05):    70.0223 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    37.3221 >        20
#  3.511e-04   2180.049 101325.000  226603.766113
#     Limiting global state vector component 1 (dt =     1e-05):    65.7066 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    34.9136 >        20
#  3.536e-04   2198.073 101325.000  221265.914481
#     Limiting global state vector component 1 (dt =     1e-05):    61.8435 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    32.7692 >        20
#  3.561e-04   2214.965 101325.000  216280.169508
#     Limiting global state vector component 1 (dt =     1e-05):    58.3638 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    30.8478 >        20
#  3.586e-04   2230.844 101325.000  211607.810100
#     Limiting global state vector component 1 (dt =     1e-05):    55.2078 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    29.1159 >        20
#  3.611e-04   2245.814 101325.000  207216.102199
#     Limiting global state vector component 1 (dt =     1e-05):    52.3401 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    27.5473 >        20
#  3.636e-04   2259.961 101325.000  203077.131343
#     Limiting global state vector component 1 (dt =     1e-05):     49.723 >        20
#     Limiting global state vector component 1 (dt =     5e-06):      26.12 >        20
#  3.661e-04   2273.362 101325.000  199166.906356
#     Limiting global state vector component 1 (dt =     1e-05):    47.3328 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    24.8158 >        20
#  3.686e-04   2286.082 101325.000  195464.661734
#     Limiting global state vector component 1 (dt =     1e-05):    45.1058 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    23.6183 >        20
#  3.711e-04   2298.178 101325.000  191952.308253
#     Limiting global state vector component 1 (dt =     1e-05):    43.0625 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    22.5161 >        20
#  3.736e-04   2309.701 101325.000  188613.995428
#     Limiting global state vector component 1 (dt =     1e-05):    41.1692 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    21.4979 >        20
#  3.761e-04   2320.694 101325.000  185435.759538
#     Limiting global state vector component 1 (dt =     1e-05):    39.4079 >        20
#     Limiting global state vector component 1 (dt =     5e-06):    20.5543 >        20
#  3.786e-04   2331.199 101325.000  182405.238188
#     Limiting global state vector component 1 (dt =     1e-05):    37.7679 >        20
#  3.836e-04   2350.877 101325.000  176744.534593
#     Limiting global state vector component 1 (dt =     1e-05):    34.8062 >        20
#  3.886e-04   2368.974 101325.000  171557.087662
#     Limiting global state vector component 1 (dt =     1e-05):    32.2008 >        20
#  3.936e-04   2385.688 101325.000  166782.362589
#     Limiting global state vector component 1 (dt =     1e-05):    29.8889 >        20
#  3.986e-04   2401.178 101325.000  162370.702564
#     Limiting global state vector component 1 (dt =     1e-05):    27.8245 >        20
#  4.036e-04   2415.579 101325.000  158280.886712
#     Limiting global state vector component 1 (dt =     1e-05):    25.9692 >        20
#  4.086e-04   2429.004 101325.000  154478.331896
#     Limiting global state vector component 1 (dt =     1e-05):    24.2924 >        20
#  4.136e-04   2441.550 101325.000  150933.745623
#     Limiting global state vector component 1 (dt =     1e-05):    22.7692 >        20
#  4.186e-04   2453.298 101325.000  147622.101162
#     Limiting global state vector component 1 (dt =     1e-05):    21.3793 >        20
#  4.236e-04   2464.320 101325.000  144521.846790
#     Limiting global state vector component 1 (dt =     1e-05):    20.1057 >        20
#  4.286e-04   2474.678 101325.000  141614.288193
#  4.386e-04   2493.612 101325.000  136313.940208
#  4.486e-04   2510.465 101325.000  131612.404515
#  4.586e-04   2525.524 101325.000  127424.004601
#  4.686e-04   2539.022 101325.000  123679.831727
#  4.786e-04   2551.152 101325.000  120323.487923
#  4.886e-04   2562.073 101325.000  117308.103273
#  4.986e-04   2571.921 101325.000  114594.197632
#  5.086e-04   2580.813 101325.000  112148.124588
#  5.186e-04   2588.850 101325.000  109940.915173
#  5.286e-04   2596.119 101325.000  107947.408090
#  5.386e-04   2602.698 101325.000  106145.585455
#  5.486e-04   2608.654 101325.000  104516.057855
#  5.586e-04   2614.049 101325.000  103041.659578
#  5.686e-04   2618.938 101325.000  101707.126160
#  5.786e-04   2623.367 101325.000  100498.833929
#  5.886e-04   2627.382 101325.000   99404.586841
#  5.986e-04   2631.021 101325.000   98413.439698
#  6.086e-04   2634.320 101325.000   97515.550995
#  6.186e-04   2637.311 101325.000   96702.055545
#  6.286e-04   2640.022 101325.000   95964.958363
#  6.386e-04   2642.480 101325.000   95297.041087
#  6.486e-04   2644.708 101325.000   94691.781153
#  6.586e-04   2646.728 101325.000   94143.280653
#  6.686e-04   2648.559 101325.000   93646.203665
#  6.786e-04   2650.220 101325.000   93195.720631
#  6.886e-04   2651.725 101325.000   92787.458838
#  6.986e-04   2653.089 101325.000   92417.458166
#  7.086e-04   2654.326 101325.000   92082.131406
#  7.186e-04   2655.447 101325.000   91778.228651
#  7.286e-04   2656.464 101325.000   91502.805191
#  7.386e-04   2657.385 101325.000   91253.192624
#  7.486e-04   2658.220 101325.000   91026.972778
#  7.586e-04   2658.977 101325.000   90821.954176
#  7.686e-04   2659.663 101325.000   90636.150714
#  7.786e-04   2660.285 101325.000   90467.762108
#  7.886e-04   2660.848 101325.000   90315.156846
#  7.986e-04   2661.359 101325.000   90176.856200
#  8.086e-04   2661.822 101325.000   90051.519855
#  8.186e-04   2662.242 101325.000   89937.933012
#  8.286e-04   2662.622 101325.000   89834.994684
#  8.386e-04   2662.967 101325.000   89741.706983
#  8.486e-04   2663.279 101325.000   89657.165460
#  8.586e-04   2663.562 101325.000   89580.550402
#  8.686e-04   2663.819 101325.000   89511.118875
#  8.786e-04   2664.051 101325.000   89448.197536
#  8.886e-04   2664.262 101325.000   89391.176136
#  8.986e-04   2664.453 101325.000   89339.501594
#  9.086e-04   2664.626 101325.000   89292.672656
#  9.186e-04   2664.783 101325.000   89250.235046
#  9.286e-04   2664.925 101325.000   89211.777050
#  9.386e-04   2665.054 101325.000   89176.925547
#  9.486e-04   2665.171 101325.000   89145.342388
#  9.586e-04   2665.277 101325.000   89116.721116
#  9.686e-04   2665.373 101325.000   89090.784004
#  9.786e-04   2665.459 101325.000   89067.279359
#  9.886e-04   2665.538 101325.000   89045.979082
#  9.986e-04   2665.610 101325.000   89026.676461
#  1.009e-03   2665.674 101325.000   89009.184164

# %% [markdown]
# 時系列データをCSVにエクスポートする

# %%
pd.DataFrame(states.species_names).to_csv('H2O2_name_species.csv', header=False, index=False)
pd.DataFrame(states.reaction_equations()).to_csv('H2O2_reaction_equations.csv', header=False, index=False)

# %%
np.savetxt('H2O2_X.csv', states.X, delimiter=',')
np.savetxt('H2O2_T.csv', states.T, delimiter=',')
np.savetxt('H2O2_time.csv', states.t, delimiter=',')
np.savetxt('H2O2_ROP.csv', states.net_rates_of_progress, delimiter=',')
np.savetxt('H2O2_mu.csv', states.reactant_stoich_coeffs, delimiter=',', fmt='%d')

# %%
positions_x = np.linspace(0.1, 0.9, len(states.species_names))
positions_y = np.ones(shape=positions_x.shape)*0.5
pd.DataFrame({'X': positions_x, 'Y': positions_y}).to_csv('H2O2_positions.csv', header=False, index=False)
